# %% [markdown]
# <a href="https://colab.research.google.com/github/AishwaryaJainM/Image-Classification/blob/master/Image_Classification_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
# !ls
# Out:
# drive  sample_data

# %%
cd /content/drive/My Drive/Smartknower-Internship
# Out:
# /content/drive/My Drive/Smartknower-Internship

# %%
# !ls
# Out:
#  Fruits_With_Color.ipynb		  'Linear Regression-Sklearn.ipynb'
# 'Image Classification.ipynb'		   Python
#  Image_Classification_Mini_Projecy.ipynb  'Untitled folder'
# 'Linear Regression - Sklearn.ipynb'

# %%
# !mkdir Images

# %%
# !ls
# Out:
#  Fruits_With_Color.ipynb		  'Linear Regression - Sklearn.ipynb'
# 'Image Classification.ipynb'		  'Linear Regression-Sklearn.ipynb'
#  Image_Classification_Mini_Projecy.ipynb   Python
#  Images					  'Untitled folder'

# %%
from bing_image_downloader import downloader
downloader.download("Elephant",limit=100,output_dir="Images")
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/thumb/3/37/African_Bush_Elephant.jpg/1200px-African_Bush_Elephant.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://upload.wikimedia.org/wikipedia/commons/thumb/b/bf/African_Elephant_%28Loxodonta_africana%29_male_%2817289351322%29.jpg/1200px-African_Elephant_%28Loxodonta_africana%29_male_%2817289351322%29.jpg
# [Error]Invalid image, not saving https://upload.wikimedia.org/wikipedia/commons/thumb/b/bf/African_Elephant_%28Loxodonta_africana%29_male_%2817289351322%29.jpg/1200px-African_Elephant_%28Loxodonta_africana%29_male_%2817289351322%29.jpg
#
# [!] Issue getting: https://upload.wikimedia.org/wikipedia/commons/thumb/b/bf/African_Elephant_%28Loxodonta_africana%29_male_%2817289351322%29.jpg/1200px-African_Elephant_%28Loxodonta_africana%29_male_%2817289351322%29.jpg
# [!] Error:: No active exception to reraise
# ...

# %%
path='/content/drive/My Drive/Smartknower-Internship/Images/Elephant/Image_11.jpg'
import cv2
import matplotlib.pyplot as plt

i = cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
downloader.download("Tiger",limit=100,output_dir="Images")
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/thumb/5/54/Tigress_at_Jim_Corbett_National_Park.jpg/1920px-Tigress_at_Jim_Corbett_National_Park.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://images.theconversation.com/files/242298/original/file-20181025-71032-1hmrk2l.jpg?ixlib=rb-1.1.0&amp;rect=0%2C584%2C5007%2C2503&amp;q=45&amp;auto=format&amp;w=1356&amp;h=668&amp;fit=crop
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Bengal_tiger_(Panthera_tigris_tigris)_female_2.jpg/1200px-Bengal_tiger_(Panthera_tigris_tigris)_female_2.jpg
# [Error]Invalid image, not saving https://upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Bengal_tiger_(Panthera_tigris_tigris)_female_2.jpg/1200px-Bengal_tiger_(Panthera_tigris_tigris)_female_2.jpg
#
# ...

# %%
import os
import cv2
path='/content/drive/My Drive/Smartknower-Internship/Images/Elephant'
  
for filename in os.listdir(path):
  i = cv2.imread(os.path.join(path,filename))
  print(i.shape)
# Out:
# (1800, 1200, 3)
# (800, 1200, 3)
# (922, 1200, 3)
# (1152, 2048, 3)
# (800, 1200, 3)
# (600, 1000, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (1600, 1067, 3)
# (1202, 1200, 3)
# (3744, 5616, 3)
# (720, 1280, 3)
# (768, 1024, 3)
# (720, 1280, 3)
# (1536, 2048, 3)
# (680, 1004, 3)
# (720, 1280, 3)
# (1200, 1600, 3)
# (2048, 1367, 3)
# (700, 1400, 3)
# (1200, 1600, 3)
# (1743, 1620, 3)
# (800, 1200, 3)
# (628, 1200, 3)
# (288, 460, 3)
# (536, 486, 3)
# (1039, 736, 3)
# (666, 864, 3)
# (360, 480, 3)
# (829, 1200, 3)
# (360, 480, 3)
# (1032, 1280, 3)
# (1000, 1600, 3)
# (900, 600, 3)
# (519, 730, 3)
# (720, 1280, 3)
# (1068, 1900, 3)
# (920, 736, 3)
# (720, 1280, 3)
# (330, 220, 3)
# (360, 480, 3)
# (350, 287, 3)
# (1000, 1600, 3)
# (768, 490, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (1441, 2562, 3)
# (621, 550, 3)
# (330, 390, 3)
# (720, 1280, 3)
# (360, 480, 3)
# (973, 1600, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (900, 1440, 3)
# (720, 1280, 3)
# (900, 1200, 3)
# ...

# %%
import os
from skimage.io import imread
from skimage.transform import resize

# %%
import numpy as np
target=[] # This is the list of target output
flatdata=[] # Image pixel in flatten style
images=[]

path='/content/drive/My Drive/Smartknower-Internship/Images/'
for dirpath,dirnames,filenames in os.walk(path):
  for filename in filenames:
    category=dirpath.split('/')[-1]
    target.append(category)
    img=imread(f'{path}{category}/{filename}')
    img_resized=resize(img,(100,100,3)) 
    flatdata.append(img_resized.flatten())
    images.append(img_resized)

flatdata=np.array(flatdata)
target=np.array(target)
images=np.array(images)

print(flatdata.shape)
print(target.shape)
print(images.shape)
# Out:
# (204, 30000)
# (204,)
# (204, 100, 100, 3)

# %%
import pandas as pd
df=pd.DataFrame(flatdata)
df['Target']=target

# %%
df.head()
# Out:
#           0         1         2  ...     29998     29999    Target
# 0  0.754902  0.813725  0.847059  ...  0.570588  0.449020  Elephant
# 1  0.886275  0.905882  0.933333  ...  0.715686  0.609804  Elephant
# 2  0.239000  0.317216  0.333118  ...  0.657294  0.416333  Elephant
# 3  0.858824  0.901961  0.972549  ...  0.169382  0.142196  Elephant
# 4  0.655882  0.725490  0.708824  ...  0.573529  0.486275  Elephant
#
# [5 rows x 30001 columns]

# %%
from sklearn.model_selection import train_test_split
flatdata_train,flatdata_test,target_train,target_test=train_test_split(flatdata,target,random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()
model.fit(flatdata,target)
target_pred=model.predict(flatdata_test)
target_pred
# Out:
# array(['Elephant', 'Elephant', 'Tiger', 'Elephant', 'Tiger', 'Tiger',
#        'Elephant', 'Tiger', 'Elephant', 'Tiger', 'Elephant', 'Tiger',
#        'Tiger', 'Tiger', 'Tiger', 'Elephant', 'Tiger', 'Tiger', 'Tiger',
#        'Elephant', 'Elephant', 'Tiger', 'Elephant', 'Tiger', 'Elephant',
#        'Tiger', 'Tiger', 'Tiger', 'Tiger', 'Elephant', 'Elephant',
#        'Tiger', 'Elephant', 'Elephant', 'Elephant', 'Tiger', 'Elephant',
#        'Elephant', 'Elephant', 'Tiger', 'Tiger', 'Tiger', 'Elephant',
#        'Tiger', 'Tiger', 'Elephant', 'Tiger', 'Elephant', 'Elephant',
#        'Tiger', 'Elephant'], dtype='<U8')

# %%
target_test
# Out:
# array(['Elephant', 'Elephant', 'Elephant', 'Elephant', 'Tiger',
#        'Elephant', 'Elephant', 'Tiger', 'Elephant', 'Tiger', 'Elephant',
#        'Tiger', 'Tiger', 'Tiger', 'Tiger', 'Elephant', 'Tiger', 'Tiger',
#        'Elephant', 'Elephant', 'Elephant', 'Tiger', 'Elephant', 'Tiger',
#        'Elephant', 'Tiger', 'Tiger', 'Tiger', 'Tiger', 'Elephant',
#        'Tiger', 'Elephant', 'Elephant', 'Elephant', 'Elephant',
#        'Elephant', 'Elephant', 'Elephant', 'Elephant', 'Tiger', 'Tiger',
#        'Tiger', 'Elephant', 'Elephant', 'Tiger', 'Tiger', 'Tiger',
#        'Elephant', 'Elephant', 'Tiger', 'Elephant'], dtype='<U8')

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(target_pred,target_test)
# Out:
# 0.8431372549019608

# %%
confusion_matrix(target_pred,target_test)
# Out:
# array([[22,  2],
#        [ 6, 21]])

# %%
i=[]
flatdata=[]
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt
i = imread('https://upload.wikimedia.org/wikipedia/commons/3/34/Bengal_Tiger_Miami_MetroZoo.jpg')
img_resized=resize(i,(100,100,3))
flatdata.append(img_resized.flatten())
i=np.array(flatdata)
i_p=model.predict(i)
i_p
# Out:
# array(['Tiger'], dtype='<U8')
